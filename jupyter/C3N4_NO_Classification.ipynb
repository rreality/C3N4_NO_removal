# %%
from training_model import GridSearch

filled_dataset_path = 'data/C3N4_NO_removal_filled.csv'

grid_search = GridSearch(filled_dataset_path)
models = [
    'LightGBM',
    # 'CatBoost',
    # 'XGBoost',
    'GradientBoost',
    'RandomForest',
    'ExtraTree',
    'DecisionTree',
    'AdaBoost',
    'KNN'
]
grid_search.process(models, cv=5)
# Out:
# ============================== LightGBM =============================
# {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'num_leaves': 31, 'objective': None, 'random_state': 47, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': 'warn', 'subsample': 1.0, 'subsample_for_bin': 200000, 'subsample_freq': 0}
# {}
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       184
#            1       1.00      1.00      1.00        20
#
#     accuracy                           1.00       204
#    macro avg       1.00      1.00      1.00       204
# weighted avg       1.00      1.00      1.00       204
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        46
# ...
